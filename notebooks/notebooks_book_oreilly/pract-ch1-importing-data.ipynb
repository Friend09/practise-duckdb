# %% [markdown]
# # Chapter 1. Importing Data into DuckDB

# %% [markdown]
# - https://learning.oreilly.com/library/view/duckdb-up-and/9781098159689/ch01.html#creating_duckdb_databases

# %% [markdown]
# # --CSV FILES

# %% [markdown]
# ## CREATE DATABASE

# %%
# creates an in memory storage
import duckdb

# conn = duckdb.connect()
conn_memory = duckdb.connect(":memory:")  # same as above

# %%
# create a persistant storage
conn_manning = duckdb.connect(
    database="../data/manning.duckdb",
    read_only=False,
)

# %% [markdown]
# ## CREATE TABLE

# %% [markdown]
# ### LOAD - EXECUTE

# %%
import duckdb

conn_manning = duckdb.connect()
conn_manning.execute(
    """
CREATE TABLE flights
AS
SELECT * FROM read_csv_auto('../data/flights.csv')
"""
).df()
# Out:
#      Count
# 0  5819079

# %%
display(conn_manning.execute("SHOW TABLES").df())
# Out:
#       name
# 0  flights

# %%
conn_manning.sql("SELECT * from flights;")
# Out:
# ┌───────┬───────┬───────┬─────────────┬───┬────────────────┬───────────────┬─────────────────────┬───────────────┐
# │ YEAR  │ MONTH │  DAY  │ DAY_OF_WEEK │ … │ SECURITY_DELAY │ AIRLINE_DELAY │ LATE_AIRCRAFT_DELAY │ WEATHER_DELAY │
# │ int64 │ int64 │ int64 │    int64    │   │     int64      │     int64     │        int64        │     int64     │
# ├───────┼───────┼───────┼─────────────┼───┼────────────────┼───────────────┼─────────────────────┼───────────────┤
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │    ·  │     · │     · │           · │ · │             ·  │            ·  │                  ·  │            ·  │
# │    ·  │     · │     · │           · │ · │             ·  │            ·  │                  ·  │            ·  │
# │    ·  │     · │     · │           · │ · │             ·  │            ·  │                  ·  │            ·  │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │              0 │             6 │                   1 │             0 │
# │  2015 │     1 │     1 │           4 │ … │              0 │            15 │                   0 │             0 │
# │  2015 │     1 │     1 │           4 │ … │              0 │            28 │                  70 │             0 │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │              0 │             7 │                  10 │             0 │
# │  2015 │     1 │     1 │           4 │ … │           NULL │          NULL │                NULL │          NULL │
# │  2015 │     1 │     1 │           4 │ … │              0 │             5 │                  11 │             0 │
# │  2015 │     1 │     1 │           4 │ … │              0 │           112 │                  63 │             0 │
# │  2015 │     1 │     1 │           4 │ … │              0 │             0 │                  20 │             1 │
# ├───────┴───────┴───────┴─────────────┴───┴────────────────┴───────────────┴─────────────────────┴───────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                             31 columns (8 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# create airports table, copy csv content into this table
conn_manning.execute(
    """
CREATE TABLE airports(
                    IATA_CODE VARCHAR,
                    AIRPORT VARCHAR,
                    CITY VARCHAR,
                    STATE VARCHAR,
                    COUNTRY VARCHAR,
                    LATITUDE VARCHAR,
                    LONGITUDE VARCHAR
                    );
COPY airports FROM '../data/airports.csv' (AUTO_DETECT TRUE);
"""
)

conn_manning.execute("SELECT * FROM airports").df()
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE   LONGITUDE
# 0                         Allentown    PA     USA  40.65236   -75.44040
# 1                           Abilene    TX     USA  32.41132   -99.68190
# 2                       Albuquerque    NM     USA  35.04022  -106.60919
# 3                          Aberdeen    SD     USA  45.44906   -98.42183
# 4                            Albany    GA     USA  31.53552   -84.19447
# ..                              ...   ...     ...       ...         ...
# 317                        Wrangell    AK     USA  56.48433  -132.36982
# 318                West Yellowstone    MT     USA  44.68840  -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187   -94.30681
# 320                         Yakutat    AK     USA  59.50336  -139.66023
# 321                            Yuma    AZ     USA  32.65658  -114.60597
#
# [322 rows x 7 columns]

# %%
# show # of tables
conn_manning.sql("SHOW TABLES")
# conn_manning.execute("SHOW TABLES").df()
# Out:
# ┌──────────┐
# │   name   │
# │ varchar  │
# ├──────────┤
# │ airports │
# │ flights  │
# └──────────┘

# %% [markdown]
# ### LOAD - REGISTER

# %%
airlines = conn_manning.execute(
    """
    SELECT
        *
    FROM read_csv('../data/airlines.csv',
                  Header = True,
                  Columns = {'IATA_CODE': 'VARCHAR', 'AIRLINE': 'VARCHAR'})
"""
).df()
airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
# now register the dataframe as table
conn_manning.register("airlines", airlines)

# %%
conn_manning.execute("SHOW TABLES").df()
# Out:
#        name
# 0  airlines
# 1  airports
# 2   flights

# %%
# check the airlines table
conn_manning.sql("SELECT * FROM airlines")
# Out:
# ┌───────────┬──────────────────────────────┐
# │ IATA_CODE │           AIRLINE            │
# │  varchar  │           varchar            │
# ├───────────┼──────────────────────────────┤
# │ UA        │ United Air Lines Inc.        │
# │ AA        │ American Airlines Inc.       │
# │ US        │ US Airways Inc.              │
# │ F9        │ Frontier Airlines Inc.       │
# │ B6        │ JetBlue Airways              │
# │ OO        │ Skywest Airlines Inc.        │
# │ AS        │ Alaska Airlines Inc.         │
# │ NK        │ Spirit Air Lines             │
# │ WN        │ Southwest Airlines Co.       │
# │ DL        │ Delta Air Lines Inc.         │
# │ EV        │ Atlantic Southeast Airlines  │
# │ HA        │ Hawaiian Airlines Inc.       │
# │ MQ        │ American Eagle Airlines Inc. │
# │ VX        │ Virgin America               │
# ├───────────┴──────────────────────────────┤
# │ 14 rows                        2 columns │
# └──────────────────────────────────────────┘

# %% [markdown]
# ## EXPORT DATA

# %%
conn_manning.sql("FROM airports").df().head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE   LONGITUDE
# 0  40.65236   -75.44040
# 1  32.41132   -99.68190
# 2  35.04022  -106.60919
# 3  45.44906   -98.42183
# 4  31.53552   -84.19447

# %%
# export data
conn_manning.execute(
    """
COPY (SELECT IATA_CODE, LATITUDE, LONGITUDE from airports)
TO '../data/airports_location.csv' WITH (HEADER 1, DELIMITER ',');
"""
)

# %%
# close connection
conn_manning.close()

# %% [markdown]
# # --PARQUET FILES

# %%
# export a file to parquet
import pandas as pd

df_airports = pd.read_csv("../data/airports.csv")
df_airports.to_parquet("../data/airports.parquet", engine="fastparquet")

# %%
# load a parquet file
import duckdb

conn = duckdb.connect()
conn.execute(
    """
CREATE TABLE airports
AS
SELECT * FROM read_parquet('../data/airports.parquet')
LIMIT 100
"""
)

# %%
conn.execute("SELECT * FROM airports").df()
# Out:
#    IATA_CODE                                          AIRPORT         CITY  \
# 0        ABE              Lehigh Valley International Airport    Allentown
# 1        ABI                         Abilene Regional Airport      Abilene
# 2        ABQ                Albuquerque International Sunport  Albuquerque
# 3        ABR                        Aberdeen Regional Airport     Aberdeen
# 4        ABY               Southwest Georgia Regional Airport       Albany
# ..       ...                                              ...          ...
# 95       EAU                 Chippewa Valley Regional Airport   Eau Claire
# 96       ECP  Northwest Florida Beaches International Airport  Panama City
# 97       EGE                    Eagle County Regional Airport        Eagle
# 98       EKO                            Elko Regional Airport         Elko
# 99       ELM                  Elmira/Corning Regional Airport       Elmira
#
#    STATE COUNTRY  LATITUDE  LONGITUDE
# 0     PA     USA  40.65236  -75.44040
# 1     TX     USA  32.41132  -99.68190
# 2     NM     USA  35.04022 -106.60919
# 3     SD     USA  45.44906  -98.42183
# 4     GA     USA  31.53552  -84.19447
# ..   ...     ...       ...        ...
# 95    WI     USA  44.86526  -91.48507
# 96    FL     USA       NaN        NaN
# 97    CO     USA  39.64257 -106.91770
# 98    NV     USA  40.82493 -115.79170
# 99    NY     USA  42.15991  -76.89144
#
# [100 rows x 7 columns]

# %%
# load last 100 rows into the table
conn.execute(
    """
INSERT INTO airports
             SELECT *
             FROM read_parquet('../data/airports.parquet')
             ORDER BY 1 DESC
             LIMIT 100
"""
)

# %%
conn.execute("SELECT * FROM airports;").df()
# Out:
#     IATA_CODE                              AIRPORT           CITY STATE  \
# 0         ABE  Lehigh Valley International Airport      Allentown    PA
# 1         ABI             Abilene Regional Airport        Abilene    TX
# 2         ABQ    Albuquerque International Sunport    Albuquerque    NM
# 3         ABR            Aberdeen Regional Airport       Aberdeen    SD
# 4         ABY   Southwest Georgia Regional Airport         Albany    GA
# ..        ...                                  ...            ...   ...
# 195       OME                         Nome Airport           Nome    AK
# 196       OMA                      Eppley Airfield          Omaha    NE
# 197       OKC            Will Rogers World Airport  Oklahoma City    OK
# 198       OGG                      Kahului Airport        Kahului    HI
# 199       OAK        Oakland International Airport        Oakland    CA
#
#     COUNTRY  LATITUDE  LONGITUDE
# 0       USA  40.65236  -75.44040
# 1       USA  32.41132  -99.68190
# 2       USA  35.04022 -106.60919
# 3       USA  45.44906  -98.42183
# 4       USA  31.53552  -84.19447
# ..      ...       ...        ...
# 195     USA  64.51220 -165.44525
# 196     USA  41.30252  -95.89417
# 197     USA  35.39309  -97.60073
# 198     USA  20.89865 -156.43046
# 199     USA  37.72129 -122.22072
#
# [200 rows x 7 columns]

# %%
conn.sql("SELECT * FROM airports;")
# Out:
# ┌───────────┬──────────────────────────────────────────────┬───────────────┬─────────┬─────────┬──────────┬────────────┐
# │ IATA_CODE │                   AIRPORT                    │     CITY      │  STATE  │ COUNTRY │ LATITUDE │ LONGITUDE  │
# │  varchar  │                   varchar                    │    varchar    │ varchar │ varchar │  double  │   double   │
# ├───────────┼──────────────────────────────────────────────┼───────────────┼─────────┼─────────┼──────────┼────────────┤
# │ ABE       │ Lehigh Valley International Airport          │ Allentown     │ PA      │ USA     │ 40.65236 │   -75.4404 │
# │ ABI       │ Abilene Regional Airport                     │ Abilene       │ TX      │ USA     │ 32.41132 │   -99.6819 │
# │ ABQ       │ Albuquerque International Sunport            │ Albuquerque   │ NM      │ USA     │ 35.04022 │ -106.60919 │
# │ ABR       │ Aberdeen Regional Airport                    │ Aberdeen      │ SD      │ USA     │ 45.44906 │  -98.42183 │
# │ ABY       │ Southwest Georgia Regional Airport           │ Albany        │ GA      │ USA     │ 31.53552 │  -84.19447 │
# │ ACK       │ Nantucket Memorial Airport                   │ Nantucket     │ MA      │ USA     │ 41.25305 │  -70.06018 │
# │ ACT       │ Waco Regional Airport                        │ Waco          │ TX      │ USA     │ 31.61129 │  -97.23052 │
# │ ACV       │ Arcata Airport                               │ Arcata/Eureka │ CA      │ USA     │ 40.97812 │ -124.10862 │
# │ ACY       │ Atlantic City International Airport          │ Atlantic City │ NJ      │ USA     │ 39.45758 │  -74.57717 │
# │ ADK       │ Adak Airport                                 │ Adak          │ AK      │ USA     │ 51.87796 │ -176.64603 │
# │  ·        │      ·                                       │  ·            │ ·       │  ·      │     ·    │      ·     │
# │  ·        │      ·                                       │  ·            │ ·       │  ·      │     ·    │      ·     │
# │  ·        │      ·                                       │  ·            │ ·       │  ·      │     ·    │      ·     │
# │ OTH       │ Southwest Oregon Regional Airport (North B…  │ North Bend    │ OR      │ USA     │ 43.41714 │ -124.24603 │
# │ ORH       │ Worcester Regional Airport                   │ Worcester     │ MA      │ USA     │ 42.26734 │  -71.87571 │
# │ ORF       │ Norfolk International Airport                │ Norfolk       │ VA      │ USA     │ 36.89461 │  -76.20122 │
# │ ORD       │ Chicago O'Hare International Airport         │ Chicago       │ IL      │ USA     │  41.9796 │  -87.90446 │
# │ ONT       │ Ontario International Airport                │ Ontario       │ CA      │ USA     │   34.056 │ -117.60119 │
# │ OME       │ Nome Airport                                 │ Nome          │ AK      │ USA     │  64.5122 │ -165.44525 │
# │ OMA       │ Eppley Airfield                              │ Omaha         │ NE      │ USA     │ 41.30252 │  -95.89417 │
# │ OKC       │ Will Rogers World Airport                    │ Oklahoma City │ OK      │ USA     │ 35.39309 │  -97.60073 │
# │ OGG       │ Kahului Airport                              │ Kahului       │ HI      │ USA     │ 20.89865 │ -156.43046 │
# │ OAK       │ Oakland International Airport                │ Oakland       │ CA      │ USA     │ 37.72129 │ -122.22072 │
# ├───────────┴──────────────────────────────────────────────┴───────────────┴─────────┴─────────┴──────────┴────────────┤
# │ 200 rows (20 shown)                                                                                        7 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
conn.execute(
    """
COPY airports
             FROM '../data/airports.parquet'
             (FORMAT PARQUET);
"""
)

# %%
conn.execute(
    """
COPY (SELECT * FROM airports LIMIT 100)
             TO
             '../data/airports_100.parquet (FORMAT PARQUET);'
"""
)

# %% [markdown]
# # --EXCEL FILES

# %%
import duckdb

conn = duckdb.connect()  # creates an in memory instance

# %%
conn.execute("INSTALL spatial")
conn.execute("LOAD spatial")

# %%
conn.execute(
    """
CREATE TABLE airports
AS
SELECT * FROM st_read
"""
).df()
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []
