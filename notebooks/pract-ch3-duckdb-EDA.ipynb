# %% [markdown]
# # Chapter 3. EDA w/ DuckDB

# %% [markdown]
# [- https://learning.oreilly.com/library/view/duckdb-up-and/9781098159689/ch02.html](https://learning.oreilly.com/library/view/duckdb-up-and/9781098159689/ch03.html#our_dataset_the_2015_flights_delay_dataset)

# %% [markdown]
# ## LOAD DATA

# %%
import duckdb

conn = duckdb.connect()  # in memory

# %%
# load fligts data
conn.execute(
    """
CREATE TABLE flights
AS
SELECT *
FROM read_csv_auto('../data/flights.csv')
"""
)

# %%
# load airports data
conn.execute(
    """
CREATE TABLE airports
AS
SELECT *
FROM read_csv_auto('../data/airports.csv')
"""
)

# %%
conn.execute(
    """
    CREATE TABLE airlines
    as
    SELECT
        *
    FROM read_csv('../data/airlines.csv',
                  Header = True,
                  Columns = {
                    'IATA_CODE': 'VARCHAR',
                    'AIRLINE': 'VARCHAR'
                  })
"""
)

# %%
# show tables
conn.execute("SHOW TABLES;").df()
# Out:
#        name
# 0  airlines
# 1  airports
# 2   flights

# %% [markdown]
# ## EDA - GEO SPATIAL DATA

# %%
import folium

# %%
# show US map
mymap = folium.Map(
    location=[47.116386, -101.2999591],
    width=950,
    height=550,
    zoom_start=3,
    tiles="openstreetmap",
)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e949e83f4a86b7a2f8eedd34d1a70b9b {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e949e83f4a86b7a2f8eedd34d1a70b9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e949e83f4a86b7a2f8eedd34d1a70b9b = L.map(
#                 &quot;map_e949e83f4a86b7a2f8eedd34d1a70b9b&quot;,
#                 {
#                     center: [47.116386, -101.2999591],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_493267aba164eabb2e6b792c6861ee3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_493267aba164eabb2e6b792c6861ee3b.addTo(map_e949e83f4a86b7a2f8eedd34d1a70b9b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

mymap = folium.Map(
    location=[47.116386, -101.299591],
    width=950,
    height=550,
    zoom_start=3,
    tiles="openstreetmap",
)

folium.TileLayer("cartodbpositron", attr="cartodbpositron").add_to(mymap)
folium.TileLayer("cartodbdark_matter", attr="cartodbdark_matter").add_to(mymap)
folium.LayerControl().add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_265075d0e6de211d9ca96c53038ea103 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_265075d0e6de211d9ca96c53038ea103&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_265075d0e6de211d9ca96c53038ea103 = L.map(
#                 &quot;map_265075d0e6de211d9ca96c53038ea103&quot;,
#                 {
#                     center: [47.116386, -101.299591],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_add80639b71cc37f96c091fc39fa3a27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_add80639b71cc37f96c091fc39fa3a27.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var tile_layer_841d5412919a5e0a9592ba958e2c215b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;cartodbpositron&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_841d5412919a5e0a9592ba958e2c215b.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var tile_layer_179b2a189b95f7408c23e9fda3e1b062 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;cartodbdark_matter&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_179b2a189b95f7408c23e9fda3e1b062.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_add80639b71cc37f96c091fc39fa3a27,
#                     &quot;cartodbpositron&quot; : tile_layer_841d5412919a5e0a9592ba958e2c215b,
#                     &quot;cartodbdarkmatter&quot; : tile_layer_179b2a189b95f7408c23e9fda3e1b062,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_6974018eaa5348e30cca4c7b22a8fe70 = L.control.layers(
#                 layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers.base_layers,
#                 layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Display all airports on the map

# %%
df = conn.execute(
    """
SELECT *
FROM airports
"""
).df()

df.shape
# Out:
# (322, 7)

# %%
df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
import math

for lat, lng, airport in zip(df["LATITUDE"], df["LONGITUDE"], df["AIRPORT"]):
    if math.isnan(lat) or math.isnan(lng):
        continue

    airport = folium.CircleMarker(
        location=[lat, lng],
        radius=4,
        color="red",
        fill=True,
        fill_color="yellow",
        fill_opacity=0.5,
        popup=airport,
    )

    airport.add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_265075d0e6de211d9ca96c53038ea103 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_265075d0e6de211d9ca96c53038ea103&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_265075d0e6de211d9ca96c53038ea103 = L.map(
#                 &quot;map_265075d0e6de211d9ca96c53038ea103&quot;,
#                 {
#                     center: [47.116386, -101.299591],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_add80639b71cc37f96c091fc39fa3a27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_add80639b71cc37f96c091fc39fa3a27.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var tile_layer_841d5412919a5e0a9592ba958e2c215b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;cartodbpositron&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_841d5412919a5e0a9592ba958e2c215b.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var tile_layer_179b2a189b95f7408c23e9fda3e1b062 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;cartodbdark_matter&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_179b2a189b95f7408c23e9fda3e1b062.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_add80639b71cc37f96c091fc39fa3a27,
#                     &quot;cartodbpositron&quot; : tile_layer_841d5412919a5e0a9592ba958e2c215b,
#                     &quot;cartodbdarkmatter&quot; : tile_layer_179b2a189b95f7408c23e9fda3e1b062,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_6974018eaa5348e30cca4c7b22a8fe70 = L.control.layers(
#                 layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers.base_layers,
#                 layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#
#             tile_layer_add80639b71cc37f96c091fc39fa3a27.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             tile_layer_841d5412919a5e0a9592ba958e2c215b.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             tile_layer_179b2a189b95f7408c23e9fda3e1b062.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var circle_marker_4f8a1df7ad625613a27b518e11f59f6c = L.circleMarker(
#                 [40.65236, -75.4404],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#         var popup_ba27ce8f7fa2256aec87cc1a6bba3a35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74d592f4318e9924428123d21fd6907f = $(`&lt;div id=&quot;html_74d592f4318e9924428123d21fd6907f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lehigh Valley International Airport&lt;/div&gt;`)[0];
#                 popup_ba27ce8f7fa2256aec87cc1a6bba3a35.setContent(html_74d592f4318e9924428123d21fd6907f);
#
#
#
#         circle_marker_4f8a1df7ad625613a27b518e11f59f6c.bindPopup(popup_ba27ce8f7fa2256aec87cc1a6bba3a35)
#         ;
#
#
#
#
#             var circle_marker_b4821fbdd6e2828a09079b2933b91af3 = L.circleMarker(
#                 [32.41132, -99.6819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;f

# %%
import math

df = conn.execute(
    """
    SELECT
    *
    FROM airports
"""
).df()

for lat, lng, airport in zip(df["LATITUDE"], df["LONGITUDE"], df["AIRPORT"]):
    if math.isnan(lat) or math.isnan(lng):
        continue

    airport = folium.Marker(
        location=[lat, lng],
        popup=airport,
        icon=folium.Icon(
            color="lightgray",  # icon to display in
            icon="plane-arrival",  # the marker
            prefix="fa",
        ),
    )
    airport.add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_265075d0e6de211d9ca96c53038ea103 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_265075d0e6de211d9ca96c53038ea103&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_265075d0e6de211d9ca96c53038ea103 = L.map(
#                 &quot;map_265075d0e6de211d9ca96c53038ea103&quot;,
#                 {
#                     center: [47.116386, -101.299591],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_add80639b71cc37f96c091fc39fa3a27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_add80639b71cc37f96c091fc39fa3a27.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var tile_layer_841d5412919a5e0a9592ba958e2c215b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;cartodbpositron&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_841d5412919a5e0a9592ba958e2c215b.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var tile_layer_179b2a189b95f7408c23e9fda3e1b062 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;cartodbdark_matter&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_179b2a189b95f7408c23e9fda3e1b062.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_add80639b71cc37f96c091fc39fa3a27,
#                     &quot;cartodbpositron&quot; : tile_layer_841d5412919a5e0a9592ba958e2c215b,
#                     &quot;cartodbdarkmatter&quot; : tile_layer_179b2a189b95f7408c23e9fda3e1b062,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_6974018eaa5348e30cca4c7b22a8fe70 = L.control.layers(
#                 layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers.base_layers,
#                 layer_control_6974018eaa5348e30cca4c7b22a8fe70_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#
#             tile_layer_add80639b71cc37f96c091fc39fa3a27.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             tile_layer_841d5412919a5e0a9592ba958e2c215b.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             tile_layer_179b2a189b95f7408c23e9fda3e1b062.addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#             var circle_marker_4f8a1df7ad625613a27b518e11f59f6c = L.circleMarker(
#                 [40.65236, -75.4404],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_265075d0e6de211d9ca96c53038ea103);
#
#
#         var popup_ba27ce8f7fa2256aec87cc1a6bba3a35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74d592f4318e9924428123d21fd6907f = $(`&lt;div id=&quot;html_74d592f4318e9924428123d21fd6907f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lehigh Valley International Airport&lt;/div&gt;`)[0];
#                 popup_ba27ce8f7fa2256aec87cc1a6bba3a35.setContent(html_74d592f4318e9924428123d21fd6907f);
#
#
#
#         circle_marker_4f8a1df7ad625613a27b518e11f59f6c.bindPopup(popup_ba27ce8f7fa2256aec87cc1a6bba3a35)
#         ;
#
#
#
#
#             var circle_marker_b4821fbdd6e2828a09079b2933b91af3 = L.circleMarker(
#                 [32.41132, -99.6819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;f

# %% [markdown]
# ### DuckDB spatial Extension

# %%
import pandas as pd

df = pd.read_csv("../data/airports.csv")
df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
from shapely.geometry import Point

df["geometry"] = df.apply(
    lambda row: Point(row["LONGITUDE"], row["LATITUDE"]).wkt, axis=1
)

df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE                     geometry
# 0  40.65236  -75.44040    POINT (-75.4404 40.65236)
# 1  32.41132  -99.68190    POINT (-99.6819 32.41132)
# 2  35.04022 -106.60919  POINT (-106.60919 35.04022)
# 3  45.44906  -98.42183   POINT (-98.42183 45.44906)
# 4  31.53552  -84.19447   POINT (-84.19447 31.53552)

# %%
conn.register("airports_2", df)

# %%
conn.install_extension("spatial")

# %%
conn.load_extension("spatial")

# %%
import leafmap

df_airports_gdf = leafmap.df_to_gdf(
    df, geometry="geometry", src_crs="EPSG:4326", dst_crs="EPSG:4326"
)

# %%
df_airports_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9137a1ee9bd5fd545982703d13396db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9137a1ee9bd5fd545982703d13396db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9137a1ee9bd5fd545982703d13396db = L.map(
#                 &quot;map_c9137a1ee9bd5fd545982703d13396db&quot;,
#                 {
#                     center: [42.38445, -120.722295],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c9137a1ee9bd5fd545982703d13396db);
#
#
#
#
#
#             var tile_layer_952be906db89d2a6fbaf12b9b8f66384 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_952be906db89d2a6fbaf12b9b8f66384.addTo(map_c9137a1ee9bd5fd545982703d13396db);
#
#
#             map_c9137a1ee9bd5fd545982703d13396db.fitBounds(
#                 [[13.48345, -176.64603], [71.28545, -64.79856]],
#                 {}
#             );
#
#
#         function geo_json_e34208bd72dfce4021d5ee2aff572b82_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e34208bd72dfce4021d5ee2aff572b82_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e34208bd72dfce4021d5ee2aff572b82_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_e34208bd72dfce4021d5ee2aff572b82_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e34208bd72dfce4021d5ee2aff572b82_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_e34208bd72dfce4021d5ee2aff572b82.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e34208bd72dfce4021d5ee2aff572b82_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e34208bd72dfce4021d5ee2aff572b82 = L.geoJson(null, {
#                 onEachFeature: geo_json_e34208bd72dfce4021d5ee2aff572b82_onEachFeature,
#
#                 style: geo_json_e34208bd72dfce4021d5ee2aff572b82_styler,
#                 pointToLayer: geo_json_e34208bd72dfce4021d5ee2aff572b82_pointToLayer,
#         });
#
#         function geo_json_e34208bd72dfce4021d5ee2aff572b82_add (data) {
#             geo_json_e34208bd72dfce4021d5ee2aff572b82
#                 .addData(data);
#         }
#             geo_json_e34208bd72dfce4021d5ee2aff572b82_add({&quot;bbox&quot;: [-176.64603, 13.48345, -64.79856, 71.28545], &quot;features&quot;: [{&quot;bbox&quot;: [-75.4404, 40.65236, -75.4404, 40.65236], &quot;geometry&quot;: {&quot;coordinates&quot;: [-75.4404, 40.65236], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AIRPORT&quot;: &quot;Lehigh Valley International Airport&quot;, &quot;CITY&quot;: &quot;Allentown&quot;, &quot;COUNTRY&quot;: &quot;USA&quot;, &quot;IATA_CODE&quot;: &quot;ABE&quot;, &quot;LATITUDE&quot;: 40.65236, &quot;LONGITUDE&quot;: -75.4404, &quot;STATE&quot;: &quot;PA&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-99.6819, 32.41132, -99.6819, 32.41132], &quot;geometry&quot;: {&quot;coordinates&quot;: [-99.6819, 32.41132], &quot;type&quot;: &quot;Point&quot;

# %%
# get co-ordinates of louisville
df.query("CITY=='Louisville'")
# Out:
#     IATA_CODE                                            AIRPORT        CITY  \
# 276       SDF  Louisville International Airport (Standiford F...  Louisville
#
#     STATE COUNTRY  LATITUDE  LONGITUDE                  geometry
# 276    KY     USA  38.17439    -85.736  POINT (-85.736 38.17439)

# %%
LOUISVILLE_LNGLAT = (-85.736, 38.17439)

# within 3 degrees
df_airports_near_louisville = conn.sql(
    f"""
    SELECT *
    FROM airports_2
    WHERE ST_DWithin(
        ST_GeomFromText(geometry),
        ST_GeomFromText('POINT ({LOUISVILLE_LNGLAT[0]} {LOUISVILLE_LNGLAT[1]})'),
        3);
"""
).df()

# %%
df_airports_near_louisville.sort_values(by="LATITUDE")
# Out:
#   IATA_CODE                                            AIRPORT          CITY  \
# 8       TYS                               McGhee Tyson Airport     Knoxville
# 0       BNA                    Nashville International Airport     Nashville
# 6       LEX                                 Blue Grass Airport     Lexington
# 3       EVV                        Evansville Regional Airport    Evansville
# 7       SDF  Louisville International Airport (Standiford F...    Louisville
# 1       CVG  Cincinnati/Northern Kentucky International Air...     Covington
# 5       IND                 Indianapolis International Airport  Indianapolis
# 2       DAY          James M. Cox Dayton International Airport        Dayton
# 4       FWA                   Fort Wayne International Airport    Fort Wayne
#
#   STATE COUNTRY  LATITUDE  LONGITUDE                    geometry
# 8    TN     USA  35.81249  -83.99286  POINT (-83.99286 35.81249)
# 0    TN     USA  36.12448  -86.67818  POINT (-86.67818 36.12448)
# 6    KY     USA  38.03697  -84.60539  POINT (-84.60539 38.03697)
# 3    IN     USA  38.03799  -87.53063  POINT (-87.53063 38.03799)
# 7    KY     USA  38.17439  -85.73600    POINT (-85.736 38.17439)
# 1    KY     USA  39.04614  -84.66217  POINT (-84.66217 39.04614)
# 5    IN     USA  39.71733  -86.29438  POINT (-86.29438 39.71733)
# 2    OH     USA  39.90238  -84.21938  POINT (-84.21938 39.90238)
# 4    IN     USA  40.97847  -85.19515  POINT (-85.19515 40.97847)

# %%
# plot the airports
import leafmap

df_airports_near_louisville_gdf = leafmap.df_to_gdf(
    df_airports_near_louisville, src_crs="EPSG:4326", dst_crs="EPSG:4326"
)

folium_map = df_airports_near_louisville_gdf.explore()
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b6d529dfa898b1aa81b4a113daf16a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b6d529dfa898b1aa81b4a113daf16a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b6d529dfa898b1aa81b4a113daf16a7 = L.map(
#                 &quot;map_7b6d529dfa898b1aa81b4a113daf16a7&quot;,
#                 {
#                     center: [38.39548, -85.76174499999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7b6d529dfa898b1aa81b4a113daf16a7);
#
#
#
#
#
#             var tile_layer_fdaa7cf0d79b30f44ef0f2b771eb006f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fdaa7cf0d79b30f44ef0f2b771eb006f.addTo(map_7b6d529dfa898b1aa81b4a113daf16a7);
#
#
#             map_7b6d529dfa898b1aa81b4a113daf16a7.fitBounds(
#                 [[35.81249, -87.53063], [40.97847, -83.99286]],
#                 {}
#             );
#
#
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_30757a1f7a5d998c9e092da34ed1a92d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_30757a1f7a5d998c9e092da34ed1a92d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_30757a1f7a5d998c9e092da34ed1a92d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_30757a1f7a5d998c9e092da34ed1a92d = L.geoJson(null, {
#                 onEachFeature: geo_json_30757a1f7a5d998c9e092da34ed1a92d_onEachFeature,
#
#                 style: geo_json_30757a1f7a5d998c9e092da34ed1a92d_styler,
#                 pointToLayer: geo_json_30757a1f7a5d998c9e092da34ed1a92d_pointToLayer,
#         });
#
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_add (data) {
#             geo_json_30757a1f7a5d998c9e092da34ed1a92d
#                 .addData(data);
#         }
#             geo_json_30757a1f7a5d998c9e092da34ed1a92d_add({&quot;bbox&quot;: [-87.53063, 35.81249, -83.99286, 40.97847], &quot;features&quot;: [{&quot;bbox&quot;: [-86.67818, 36.12448, -86.67818, 36.12448], &quot;geometry&quot;: {&quot;coordinates&quot;: [-86.67818, 36.12448], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AIRPORT&quot;: &quot;Nashville International Airport&quot;, &quot;CITY&quot;: &quot;Nashville&quot;, &quot;COUNTRY&quot;: &quot;USA&quot;, &quot;IATA_CODE&quot;: &quot;BNA&quot;, &quot;LATITUDE&quot;: 36.12448, &quot;LONGITUDE&quot;: -86.67818, &quot;STATE&quot;: &quot;TN&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-84.66217, 39.04614, -84.66217, 39.04614], &quot;geometry&quot;: {&quot;coordinates&quot;: [-84.66217, 39.04614], &quot;type&quot;: &quot;Poi

# %%
import folium

folium.Marker(
    location=[LOUISVILLE_LNGLAT[1], LOUISVILLE_LNGLAT[0]], popup="Louisville"
).add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b6d529dfa898b1aa81b4a113daf16a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b6d529dfa898b1aa81b4a113daf16a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b6d529dfa898b1aa81b4a113daf16a7 = L.map(
#                 &quot;map_7b6d529dfa898b1aa81b4a113daf16a7&quot;,
#                 {
#                     center: [38.39548, -85.76174499999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7b6d529dfa898b1aa81b4a113daf16a7);
#
#
#
#
#
#             var tile_layer_fdaa7cf0d79b30f44ef0f2b771eb006f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fdaa7cf0d79b30f44ef0f2b771eb006f.addTo(map_7b6d529dfa898b1aa81b4a113daf16a7);
#
#
#             map_7b6d529dfa898b1aa81b4a113daf16a7.fitBounds(
#                 [[35.81249, -87.53063], [40.97847, -83.99286]],
#                 {}
#             );
#
#
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_30757a1f7a5d998c9e092da34ed1a92d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_30757a1f7a5d998c9e092da34ed1a92d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_30757a1f7a5d998c9e092da34ed1a92d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_30757a1f7a5d998c9e092da34ed1a92d = L.geoJson(null, {
#                 onEachFeature: geo_json_30757a1f7a5d998c9e092da34ed1a92d_onEachFeature,
#
#                 style: geo_json_30757a1f7a5d998c9e092da34ed1a92d_styler,
#                 pointToLayer: geo_json_30757a1f7a5d998c9e092da34ed1a92d_pointToLayer,
#         });
#
#         function geo_json_30757a1f7a5d998c9e092da34ed1a92d_add (data) {
#             geo_json_30757a1f7a5d998c9e092da34ed1a92d
#                 .addData(data);
#         }
#             geo_json_30757a1f7a5d998c9e092da34ed1a92d_add({&quot;bbox&quot;: [-87.53063, 35.81249, -83.99286, 40.97847], &quot;features&quot;: [{&quot;bbox&quot;: [-86.67818, 36.12448, -86.67818, 36.12448], &quot;geometry&quot;: {&quot;coordinates&quot;: [-86.67818, 36.12448], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AIRPORT&quot;: &quot;Nashville International Airport&quot;, &quot;CITY&quot;: &quot;Nashville&quot;, &quot;COUNTRY&quot;: &quot;USA&quot;, &quot;IATA_CODE&quot;: &quot;BNA&quot;, &quot;LATITUDE&quot;: 36.12448, &quot;LONGITUDE&quot;: -86.67818, &quot;STATE&quot;: &quot;TN&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-84.66217, 39.04614, -84.66217, 39.04614], &quot;geometry&quot;: {&quot;coordinates&quot;: [-84.66217, 39.04614], &quot;type&quot;: &quot;Poi

# %% [markdown]
# ## PERFORMING DESCRIPTIVE ANLYTICS
